# %%
# !pip install schrutepy
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# !pip install wordcloud
# !pip install nltk
from schrutepy import schrutepy
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import nltk
from nltk.corpus import stopwords
from PIL import Image
import collections
import pandas as pd
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = schrutepy.load_schrute()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>index</th>
#       <th>season</th>
#       <th>episode</th>
#       <th>episode_name</th>
#       <th>director</th>
#       <th>writer</th>
#       <th>character</th>
#       <th>text</th>
#       <th>text_w_direction</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>Pilot</td>
#       <td>Ken Kwapis</td>
#       <td>Ricky Gervais;Stephen Merchant;Greg Daniels</td>
#       <td>Michael</td>
#       <td>All right Jim. Your quarterlies look very good...</td>
#       <td>All right Jim. Your quarterlies look very good...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>1</td>
#       <td>1</td>
#       <td>Pilot</td>
#       <td>Ken Kwapis</td>
#       <td>Ricky Gervais;Stephen Merchant;Greg Daniels</td>
#       <td>Jim</td>
#       <td>Oh, I told you. I couldn't close it. So...</td>
#       <td>Oh, I told you. I couldn't close it. So...</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>1</td>
#       <td>1</td>
#       <td>Pilot</td>
#       <td>Ken Kwapis</td>
#       <td>Ricky Gervais;Stephen Merchant;Greg Daniels</td>
#       <td>Michael</td>
#       <td>So you've come to the master for guidance? Is ...</td>
#       <td>So you've come to the master for guidance? Is ...</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>1</td>
#       <td>1</td>
#       <td>Pilot</td>
#       <td>Ken Kwapis</td>
#       <td>Ricky Gervais;Stephen Merchant;Greg Daniels</td>
#       <td>Jim</td>
#       <td>Actually, you called me in here, but yeah.</td>
#       <td>Actually, you called me in here, but yeah.</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>1</td>
#       <td>1</td>
#       <td>Pilot</td>
#       <td>Ken Kwapis</td>
#       <td>Ricky Gervais;Stephen Merchant;Greg Daniels</td>
#       <td>Michael</td>
#       <td>All right. Well, let me show you how it's done.</td>
#       <td>All right. Well, let me show you how it's done.</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df = schrutepy.load_schrute()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = df.dropna()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
text = " ".join(review for review in df.text)
print ("There are {} words ins the combination of all review.".format(len(text)))
nltk.download("stopwords")
stopWords = set(stopwords.words("english"))
wordcloud=WordCloud(stopwords=stopWords,background_color="white").generate(text)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">There are 3001517 words ins the combination of all review.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# </div>

# %%
plt.figure(figsize=[30 ,15])
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
display()
